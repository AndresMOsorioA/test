# %% [markdown]
# Nombre: Andrés Mauricio Osorio Arizabaleta

# %%
import pandas as pd
df = pd.read_csv("data/WHO.csv")
df
# Out:
#                 Country  CountryID  Continent  Adolescent fertility rate (%)  \
# 0           Afghanistan          1          1                          151.0
# 1               Albania          2          2                           27.0
# 2               Algeria          3          3                            6.0
# 3               Andorra          4          2                            NaN
# 4                Angola          5          3                          146.0
# ..                  ...        ...        ...                            ...
# 197             Vietnam        198          6                           25.0
# 198  West Bank and Gaza        199          1                            NaN
# 199               Yemen        200          1                           83.0
# 200              Zambia        201          3                          161.0
# 201            Zimbabwe        202          3                          101.0
#
#      Adult literacy rate (%)  \
# ...

# %% [markdown]
# 1) ¿Cuál és la media de la población urbana (“Urban_population”) de todos los países? ¿Su desviación típica (std)?

# %%
UrbanPop = df["Urban_population"]
print("La media de la población urbana de todos los paises es " + str(UrbanPop.mean()))
print("La desviación estandar de la población urbana de todos los paises es " + str(UrbanPop.std()))
# Out:
# La media de la población urbana de todos los paises es 16657626.767446807
# La desviación estandar de la población urbana de todos los paises es 50948665.823935635

# %% [markdown]
# 2) Consulta la fila del país: “Spain”

# %%
Paises = df["Country"]
Espanya = df[Paises == "Spain"]
Espanya
# Out:
#     Country  CountryID  Continent  Adolescent fertility rate (%)  \
# 168   Spain        169          2                           10.0
#
#      Adult literacy rate (%)  \
# 168                     97.2
#
#      Gross national income per capita (PPP international $)  \
# 168                                            28200.0
#
#      Net primary school enrolment ratio female (%)  \
# 168                                           99.0
#
#      Net primary school enrolment ratio male (%)  \
# 168                                        100.0
#
#      Population (in thousands) total  Population annual growth rate (%)  ...  \
# 168                          43887.0                                1.1  ...
#
#      Total_CO2_emissions  Total_income  Total_reserves  \
# 168            343701.53  6.780000e+11             NaN
#
#      Trade_balance_goods_and_services  Under_five_mortality_from_CME  \
# 168                     -5.770000e+10                            4.9
#
# ...

# %% [markdown]
# 3a) ¿Qué país tiene una mayor población urbana?

# %%
UrbanPop = df["Urban_population"]
mayorUrbanPopFila = df[UrbanPop == UrbanPop.max()]
mayorUrbanPopPais = mayorUrbanPopFila["Country"].values[0]
mayorUrbanPopPais
print("El pais con la mayor población urbana es "+mayorUrbanPopPais)
# Out:
# El pais con la mayor población urbana es China

# %% [markdown]
# 3b) ¿Qué paises tienen una población urbana menor a 50000 ?

# %%
UrbanPop = df["Urban_population"]
UrbanPopMenorA50000 = df[UrbanPop < 50000]
UrbanPopMenorA50000Paises = UrbanPopMenorA50000["Country"].values

i = 0
print("Los paises que tienen una población urbana menor a 50000 son: ")
while i < len(UrbanPopMenorA50000Paises):
    print(UrbanPopMenorA50000Paises[i])
    i = i+1
# Out:
# Los paises que tienen una población urbana menor a 50000 son:
# Antigua and Barbuda
# Grenada
# Kiribati
# Saint Kitts and Nevis
# Saint Lucia
# Samoa
# Seychelles
# Tonga

# %% [markdown]
# 4) ¿El continente donde está situado Spain es el mismo que el de `United States of America? Utiliza una condición para obtener un resultado Booleano (True o False)

# %%
Paises = df["Country"]
Espanya = df[Paises == "Spain"]
USA = df[Paises == "United States of America"]
EspanyaContinente = Espanya["Continent"].values[0]
USAContinente = USA["Continent"].values[0]
bool = True
if EspanyaContinente != USAContinente:
    bool = False

print("Spain está situado en el continente "+ str(EspanyaContinente))
print("United States of America está situado en el continente "+ str(USAContinente))
print("Por ende la afirmación de que el continente donde está situado Spain es el mismo que el de United States of America es "+str(bool))
# Out:
# Spain está situado en el continente Europa
# United States of America está situado en el continente América del Norte
# Por ende la afirmación de que el continente donde está situado Spain es el mismo que el de United States of America es False

# %% [markdown]
# 5) ¿Cuáles son los cinco paises más contaminantes (“Total_CO2_emissions”)?

# %%
Paises = df["Country"]
Emision = df["Total_CO2_emissions"]
EmisionEnOrden = Emision.sort_values(ascending = False)
MayorEmision = EmisionEnOrden.head(5)
a = MayorEmision.index[0]
b = MayorEmision.index[1]
c = MayorEmision.index[2]
d = MayorEmision.index[3]
e = MayorEmision.index[4]

a2 = Paises[Paises.index == a].values[0]
b2= Paises[Paises.index == b].values[0]
c2= Paises[Paises.index == c].values[0]
d2= Paises[Paises.index == d].values[0]
e2= Paises[Paises.index == e].values[0]

print("Los 5 paises mas contaminantes son: ")

print(a2)
print(b2)
print(c2)
print(d2)
print(e2)
# Out:
# Los 5 paises mas contaminantes son:
# United States of America
# China
# Russia
# India
# Japan

# %% [markdown]
# 6) Observando algunas muestras del fichero puedes establecer la relación entre el identificador del continente y su nombre?
#
# Es decir, sabemos que Spain está en el continente Europeo y el código del continente es el 2.
#
# Existen los códigos de continentes: 1, 2, 3, 4, 5, 6, 7
#
# Nota: Hay dos códigos asociados a Asia.
#
# Haz las consultas pertinentes al dataframe para construir un diccionario con la siguiente estructura:
#
# codigoContinentes = {1:"Asia",2:"Europa"} #Al menos hay 7!
# print(codigoContinentes[2])
# codigoContinentes[3] = ""
# codigoContinentes[4] = ""
# codigoContinentes[5] = ""
# codigoContinentes[6] = ""
# codigoContinentes[7] = ""

# %%
Continent = df["Continent"]
Continent1 = df[Continent==1]
print(Continent1["Country"].values, end="\n\n")

Continent2 = df[Continent==2]
print(Continent2["Country"].values, end="\n\n")

Continent3 = df[Continent==3]
print(Continent3["Country"].values, end="\n\n")

Continent4 = df[Continent==4]
print(Continent4["Country"].values, end="\n\n")

Continent5 = df[Continent==5]
print(Continent5["Country"].values, end="\n\n")

Continent6 = df[Continent==6]
print(Continent6["Country"].values, end="\n\n")

Continent7 = df[Continent==7]
print(Continent7["Country"].values, end="\n\n")

codigoContinentes = {1:"Mundo Árabe (Medio Oriente)",2:"Europa",3:"África subsahariana",4:"América del Norte",5:"América Central y del Sur",6:"Asia Oriental y Oceanía",7:"Sur de Asia"}

print(codigoContinentes,end="\n\n")

print(codigoContinentes[1])
print(codigoContinentes[2])
print(codigoContinentes[3])
print(codigoContinentes[4])
print(codigoContinentes[5])
print(codigoContinentes[6])
print(codigoContinentes[7])
# Out:
# ['Afghanistan' 'Bahrain' 'Cape Verde' 'Djibouti' 'Egypt'
#  'Iran (Islamic Republic of)' 'Iraq' 'Israel' 'Jordan' 'Kuwait'
#  'Libyan Arab Jamahiriya' 'Malta' 'Morocco' 'Oman' 'Qatar' 'Saudi Arabia'
#  'Syria' 'Tunisia' 'United Arab Emirates' 'West Bank and Gaza' 'Yemen']
#
# ['Albania' 'Andorra' 'Armenia' 'Austria' 'Azerbaijan' 'Belarus' 'Belgium'
#  'Bosnia and Herzegovina' 'Bulgaria' 'Croatia' 'Cyprus' 'Czech Republic'
#  'Denmark' 'Estonia' 'Finland' 'France' 'Georgia' 'Germany' 'Greece'
#  'Hungary' 'Iceland' 'Ireland' 'Italy' 'Kazakhstan' 'Kyrgyzstan' 'Latvia'
#  'Lithuania' 'Luxembourg' 'Macedonia' 'Moldova' 'Monaco' 'Montenegro'
#  'Netherlands' 'Norway' 'Poland' 'Portugal' 'Romania' 'Russia'
#  'San Marino' 'Serbia' 'Slovakia' 'Slovenia' 'Spain' 'Sweden'
#  'Switzerland' 'Tajikistan' 'Turkey' 'Turkmenistan' 'Ukraine'
#  'United Kingdom' 'Uzbekistan']
#
# ['Algeria' 'Angola' 'Benin' 'Botswana' 'Burkina Faso' 'Burundi' 'Cameroon'
# ...

# %% [markdown]
# 7) Una vez identificado el nombre de los continentes, ¿puedes cambiar la columna de identificadores de continentes por sus respectivos nombres?

# %%
Continentes = df["Continent"]
codigoContinentes = {1:"Mundo Árabe o Medio Oriente",2:"Europa",3:"África subsahariana",4:"América del Norte",5:"América Central y del Sur",6:"Asia Oriental y Oceanía",7:"Sur de Asia"}

df2 = df





df2.loc[0,"Continent"]
i = 0
while i < 202:
    if(df2.loc[i,"Continent"]==1):
        df2.at[i, 'Continent'] = codigoContinentes[1]
    elif(df2.loc[i,"Continent"]==2):
        df2.at[i, 'Continent'] = codigoContinentes[2]
    elif(df2.loc[i,"Continent"]==3):
        df2.at[i, 'Continent'] = codigoContinentes[3]
    elif(df2.loc[i,"Continent"]==4):
        df2.at[i, 'Continent'] = codigoContinentes[4]
    elif(df2.loc[i,"Continent"]==5):
        df2.at[i, 'Continent'] = codigoContinentes[5]
    elif(df2.loc[i,"Continent"]==6):
        df2.at[i, 'Continent'] = codigoContinentes[6]
    elif(df2.loc[i,"Continent"]==7):
        df2.at[i, 'Continent'] = codigoContinentes[7]
        
        
    i = i+1
    
print(df2["Continent"].values)
df2.head(20)
# Out:
# ['Mundo Árabe (Medio Oriente)' 'Europa' 'África subsahariana' 'Europa'
#  'África subsahariana' 'América del Norte' 'América Central y del Sur'
#  'Europa' 'Asia Oriental y Oceanía' 'Europa' 'Europa' 'América del Norte'
#  'Mundo Árabe (Medio Oriente)' 'Sur de Asia' 'América del Norte' 'Europa'
#  'Europa' 'América Central y del Sur' 'África subsahariana'
#  'América del Norte' 'Sur de Asia' 'América Central y del Sur' 'Europa'
#  'África subsahariana' 'América Central y del Sur'
#  'Asia Oriental y Oceanía' 'Europa' 'África subsahariana'
#  'África subsahariana' 'Sur de Asia' 'África subsahariana'
#  'América del Norte' 'Mundo Árabe (Medio Oriente)' 'África subsahariana'
#  'África subsahariana' 'América Central y del Sur' 'Sur de Asia'
#  'América Central y del Sur' 'África subsahariana' 'África subsahariana'
#  'África subsahariana' 'Asia Oriental y Oceanía'
#  'América Central y del Sur' 'África subsahariana' 'Europa'
#  'América Central y del Sur' 'Europa' 'Europa' 'Europa'
# ...

# %% [markdown]
# 8) Puedes crear un nuevo dataframe con aquellos paises que sean de Europa?

# %%
df2 = df
Continentes = df2["Continent"]
Europa = df[Continent==2]
Europa
# Out:
#                     Country  CountryID  Continent  \
# 1                   Albania          2          2
# 3                   Andorra          4          2
# 7                   Armenia          8          2
# 9                   Austria         10          2
# 10               Azerbaijan         11          2
# 15                  Belarus         16          2
# 16                  Belgium         17          2
# 22   Bosnia and Herzegovina         23          2
# 26                 Bulgaria         27          2
# 44                  Croatia         45          2
# 46                   Cyprus         47          2
# 47           Czech Republic         48          2
# 48                  Denmark         49          2
# 57                  Estonia         58          2
# 60                  Finland         61          2
# 61                   France         62          2
# 65                  Georgia         66          2
# 66                  Germany         67          2
# ...

# %% [markdown]
# 9) ¿Cuáles son los paises más contaminantes de Europa?

# %%
df2 = df
Continentes = df2["Continent"]
Europa = df[Continent==2]
Europa

Europa
PaisesE = Europa["Country"]
EmisionE = Europa["Total_CO2_emissions"]
EmisionEnOrdenE = EmisionE.sort_values(ascending = False)

EmisionEnOrdenETop5 = EmisionEnOrdenE.head(5)
a = EmisionEnOrdenETop5.index[0]
b = EmisionEnOrdenETop5.index[1]
c = EmisionEnOrdenETop5.index[2]
d = EmisionEnOrdenETop5.index[3]
e = EmisionEnOrdenETop5.index[4]

a2 = Paises[Paises.index == a].values[0]
b2= Paises[Paises.index == b].values[0]
c2= Paises[Paises.index == c].values[0]
d2= Paises[Paises.index == d].values[0]
e2= Paises[Paises.index == e].values[0]

print("Los 5 paises mas contaminantes de Europa son: ")

print(a2)
print(b2)
print(c2)
print(d2)
print(e2)
# Out:
# Los 5 paises mas contaminantes de Europa son:
# Russia
# Germany
# United Kingdom
# Italy
# France

# %% [markdown]
# 10) Calcula la cantidad de ayuda recibida por cada municipio en función del númeto total de habitantes.

# %%
import pandas as pd
import random

random.seed(0)

nombres = [f'Municipio{i}' for i in range(1, 11)]

data_municipios = {
    'Nombre': nombres,
    'Código Postal': [random.randint(10000, 99999) for _ in range(10)],
    'Población': [random.randint(1000, 50000) for _ in range(10)]  # Añadimos un atributo aleatorio, en este caso "Población"
}

df_municipios = pd.DataFrame(data_municipios)


data_ayudas = {
    'Nombre': [random.choice(nombres) for _ in range(20)],
    'Ayuda Económica (en euros)': [random.randint(1000, 10000) for _ in range(20)],
    'Número de Beneficiarios': [random.randint(10, 100) for _ in range(20)]
}

df_ayudas = pd.DataFrame(data_ayudas)

print("Dataframe de Municipios:")
print(df_municipios)

print("\nDataframe de Ayudas:")
print(df_ayudas)
# Out:
# Dataframe de Municipios:
#         Nombre  Código Postal  Población
# 0   Municipio1          60494      39232
# 1   Municipio2          65125      15315
# 2   Municipio3          15306      34075
# 3   Municipio4          43936      10127
# 4   Municipio5          77013      19470
# 5   Municipio6          73691      10158
# 6   Municipio7          63075       7214
# 7   Municipio8          49755      41525
# 8   Municipio9          72468      17417
# 9  Municipio10          56930      35902
#
# Dataframe de Ayudas:
#          Nombre  Ayuda Económica (en euros)  Número de Beneficiarios
# 0   Municipio10                        9989                       72
# 1    Municipio3                        1230                       23
# 2    Municipio5                        2528                       48
# 3    Municipio2                        7534                       80
# 4    Municipio2                        1018                       47
# ...
